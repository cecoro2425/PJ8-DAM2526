# %%
# Setup: carregar el CSV i preparar columnes útils
import pandas as pd
import numpy as np

# Llegeix el CSV. Nota: alguns camps són strings numèrics; els convertirem a numèrics.
#df = pd.read_csv('climate_change.csv')
di = pd.read_csv('climate_change_refact.csv')
df=di.round(2)

print('Files, Columnes:', df.shape)
print('Columnes:', list(df.columns))
df.head(5)
# Out:
# Files, Columnes: (10000, 15)
# Columnes: ['Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C', 'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA', 'Extreme_Weather_Events', 'Irrigation_Access_%', 'Pesticide_Use_KG_per_HA', 'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index', 'Adaptation_Strategies', 'Economic_Impact_Million_USD']
#    Year    Country     Region Crop_Type  Average_Temperature_C  \
# 0  1990  Argentina     Pampas     Wheat                  15.54
# 1  1990  Argentina  Northeast    Fruits                  15.38
# 2  1990  Argentina  Northeast      Corn                  15.58
# 3  1990  Argentina  Northeast    Coffee                  15.80
# 4  1990  Argentina     Pampas    Coffee                  15.36
#
#    Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 0                 1406.12             15.37                  4.87
# 1                 1493.71             15.37                  5.59
# 2                 1425.17             15.36                  6.25
# 3                 1591.37             15.38                  6.89
# 4                 1846.56             15.35                  7.37
#
#    Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 0                       8                61.06                    20.34
# 1                       8                61.33                    43.73
# 2                       0                97.23                    37.02
# 3                       8                80.49                    26.03
# 4                      10                16.76                     3.61
#
#    Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 0                     60.94              64.41            No Adaptation
# 1                     23.63              63.20  Drought-resistant Crops
# 2                     51.92              62.45            Crop Rotation
# 3                     56.52              61.54            No Adaptation
# 4                     35.97              61.93            Crop Rotation
#
#    Economic_Impact_Million_USD
# 0                       493.91
# 1                       516.45
# 2                       663.72
# 3                       637.10
# 4                       430.36

# %%
df_small = df.loc[:, ['Country']].copy()
df_small['Country'].unique()
# Out:
# array(['Argentina', 'Australia', 'Brazil', 'Canada', 'China', 'France',
#        'India', 'Nigeria', 'Russia', 'USA'], dtype=object)

# %%
df_small_regions = df.loc[:, ['Region']].copy()
df_small_regions['Region'].unique()
# Out:
# array(['Pampas', 'Northeast', 'Patagonia', 'Northwest', 'New South Wales',
#        'Western Australia', 'Victoria', 'Queensland', 'North', 'South',
#        'Southeast', 'Quebec', 'British Columbia', 'Prairies', 'Ontario',
#        'East', 'Central', 'Grand Est', 'Provence-Alpes-Cote d’Azur',
#        'Nouvelle-Aquitaine', 'Ile-de-France', 'West Bengal', 'Punjab',
#        'Tamil Nadu', 'Maharashtra', 'North West', 'South West',
#        'South East', 'North Central', 'Siberian', 'Northwestern', 'Volga',
#        'Midwest', 'West'], dtype=object)

# %%
df_small_crops = df.loc[:, ['Crop_Type']].copy()
df_small_crops['Crop_Type'].unique()
# Out:
# array(['Wheat', 'Fruits', 'Corn', 'Coffee', 'Vegetables', 'Barley',
#        'Cotton', 'Rice', 'Soybeans', 'Sugarcane'], dtype=object)

# %%
mask0 = (df['Year'] == 2024) & (df['Country'] == 'India')
filtered0 = df.loc[mask0, ['Year','Country','Region','Crop_Type','Average_Temperature_C','Adaptation_Strategies','Economic_Impact_Million_USD']]
print(filtered0.head(20))
# Out:
#       Year Country       Region   Crop_Type  Average_Temperature_C  \
# 6951  2024   India  Maharashtra  Vegetables                  15.65
# 6952  2024   India       Punjab       Wheat                  14.99
# 6953  2024   India  Maharashtra       Wheat                  15.19
# 6954  2024   India       Punjab      Coffee                  15.10
# 6955  2024   India   Tamil Nadu        Corn                  14.91
# 6956  2024   India  Maharashtra      Coffee                  15.38
# 6957  2024   India       Punjab      Barley                  15.80
# 6958  2024   India   Tamil Nadu        Corn                  16.02
# 6959  2024   India  West Bengal  Vegetables                  15.38
# 6960  2024   India  Maharashtra    Soybeans                  15.63
# 6961  2024   India   Tamil Nadu    Soybeans                  15.41
# 6962  2024   India   Tamil Nadu  Vegetables                  15.48
# 6963  2024   India  West Bengal      Fruits                  15.27
# 6964  2024   India       Punjab      Cotton                  15.40
# 6965  2024   India       Punjab      Cotton                  15.49
# 6966  2024   India   Tamil Nadu        Corn                  15.21
# 6967  2024   India       Punjab  Vegetables                  15.33
# 6968  2024   India  Maharashtra   Sugarcane                  15.34
# 6969  2024   India       Punjab      Coffee                  15.56
# 6970  2024   India  West Bengal    Soybeans                  15.09
#
#         Adaptation_Strategies  Economic_Impact_Million_USD
# 6951            No Adaptation                       789.34
# 6952         Water Management                       758.91
# 6953            Crop Rotation                       807.88
# 6954            Crop Rotation                       894.03
# 6955            No Adaptation                       755.10
# 6956         Water Management                       763.96
# 6957  Drought-resistant Crops                       721.06
# 6958            No Adaptation                       905.11
# 6959  Drought-resistant Crops                       859.77
# 6960          Organic Farming                       841.89
# 6961         Water Management                       886.21
# 6962         Water Management                       694.96
# 6963          Organic Farming                       827.33
# 6964            Crop Rotation                       789.28
# 6965  Drought-resistant Crops                       676.93
# 6966            Crop Rotation                       863.03
# 6967  Drought-resistant Crops                       685.22
# 6968            No Adaptation                      1010.46
# 6969            No Adaptation                       971.17
# 6970            No Adaptation                       765.26

# %%
#Filtra con booleanos
mask = (df['Year'] == 2024) & (df['Country'] == 'Brazil') & (df['Region'] == 'North') 
filtered = df.loc[mask, ['Year','Country','Region','Crop_Type','Average_Temperature_C','Adaptation_Strategies','Economic_Impact_Million_USD']]
print(filtered.head(20))
# Out:
#       Year Country Region  Crop_Type  Average_Temperature_C  \
# 2935  2024  Brazil  North     Coffee                  16.44
# 2951  2024  Brazil  North     Cotton                  16.26
# 2953  2024  Brazil  North   Soybeans                  16.45
# 2955  2024  Brazil  North  Sugarcane                  16.51
#
#         Adaptation_Strategies  Economic_Impact_Million_USD
# 2935  Drought-resistant Crops                       823.69
# 2951         Water Management                       695.68
# 2953            Crop Rotation                       883.59
# 2955  Drought-resistant Crops                       756.71

# %%
import pandas as pd

# 1. Limpieza: Imputación de nulos por la media
# Seleccionamos solo columnas numéricas para evitar errores con fechas o texto
df_clean = df.copy()
numeric_cols = df_clean.select_dtypes(include=['number']).columns
df_clean[numeric_cols] = df_clean[numeric_cols].fillna(df_clean[numeric_cols].mean())

# 2. Definición de la máscara de filtrado
mask = (df_clean['Country'] == 'Brazil') & \
       (df_clean['Region'] == 'North') & \
       (df_clean['Crop_Type'] == 'Wheat')

# 3. Selección de columnas específicas
columns_to_show = [
    'Year', 'Country', 'Region', 'Crop_Type', 'Average_Temperature_C', 
    'Total_Precipitation_mm', 'CO2_Emissions_MT', 'Crop_Yield_MT_per_HA', 
    'Extreme_Weather_Events', 'Irrigation_Access_%', 'Pesticide_Use_KG_per_HA', 
    'Fertilizer_Use_KG_per_HA', 'Soil_Health_Index', 'Adaptation_Strategies', 
    'Economic_Impact_Million_USD'
]

# 4. Aplicar filtro y ordenar por año
# Usamos .loc para evitar el SettingWithCopyWarning
ordenado = df_clean.loc[mask, columns_to_show].sort_values(by='Year', ascending=True)

# 5. Visualización de resultados
print(f"Nulos restantes en el dataset: {df_clean.isna().sum().sum()}")
print(ordenado.head(20))
# Out:
#       Year Country Region Crop_Type  Average_Temperature_C  \
# 2044  1991  Brazil  North     Wheat                  15.20
# 2048  1991  Brazil  North     Wheat                  15.33
# 2053  1991  Brazil  North     Wheat                  15.33
# 2089  1993  Brazil  North     Wheat                  15.81
# 2106  1993  Brazil  North     Wheat                  15.22
# 2163  1995  Brazil  North     Wheat                  15.77
# 2224  1997  Brazil  North     Wheat                  15.37
# 2311  2000  Brazil  North     Wheat                  16.04
# 2372  2002  Brazil  North     Wheat                  15.67
# 2378  2003  Brazil  North     Wheat                  15.55
# 2446  2005  Brazil  North     Wheat                  15.76
# 2456  2006  Brazil  North     Wheat                  15.56
# 2479  2007  Brazil  North     Wheat                  15.90
# 2488  2007  Brazil  North     Wheat                  15.74
# 2493  2007  Brazil  North     Wheat                  16.09
# 2497  2007  Brazil  North     Wheat                  15.66
# 2502  2007  Brazil  North     Wheat                  15.65
# 2581  2011  Brazil  North     Wheat                  15.91
# 2617  2012  Brazil  North     Wheat                  15.85
# 2622  2012  Brazil  North     Wheat                  15.85
#
#       Total_Precipitation_mm  CO2_Emissions_MT  Crop_Yield_MT_per_HA  \
# 2044                 1948.61             15.15                  12.0
# 2048                 1795.83             15.17                  12.0
# 2053                 1403.75             15.17                  12.0
# 2089                 1085.93             15.47                  12.0
# 2106                 1525.24             15.48                  12.0
# 2163                 1571.23             15.77                  12.0
# 2224                 1416.18             16.08                  12.0
# 2311                 1661.10             16.53                  12.0
# 2372                 1683.76             16.81                  12.0
# 2378                 1664.40             16.97                  12.0
# 2446                 1372.93             17.27                  12.0
# 2456                 1762.46             17.42                  12.0
# 2479                 1142.46             17.55                  12.0
# 2488                 1555.56             17.56                  12.0
# 2493                 1222.76             17.58                  12.0
# 2497                 1732.34             17.56                  12.0
# 2502                 1380.77             17.58                  12.0
# 2581                 1466.58             18.19                  12.0
# 2617                 1689.08             18.31                  12.0
# 2622                 1390.81             18.31                  12.0
#
#       Extreme_Weather_Events  Irrigation_Access_%  Pesticide_Use_KG_per_HA  \
# 2044                      10                66.47                    18.72
# 2048                       8                86.65                    38.24
# 2053                       4               100.00                     5.92
# 2089                       5                64.98                    32.97
# 2106                       2                85.02                    26.73
# 2163                       8                79.00                    30.14
# 2224                       4                94.49                    29.36
# 2311                       2                14.70                    37.76
# 2372                       6                79.35                    45.30
# 2378                      10                24.62                    14.57
# 2446                       8                38.42                    47.49
# 2456                       8                35.39                     1.18
# 2479                       0                46.86                    48.08
# 2488                       6                28.24                    37.21
# 2493                       4                69.40                    15.43
# 2497                       8                29.56                    14.33
# 2502                      10                22.85                    45.77
# 2581                       5                81.92                    10.79
# 2617                       2                55.90                    36.87
# 2622                       6                83.50                     6.22
#
#       Fertilizer_Use_KG_per_HA  Soil_Health_Index    Adaptation_Strategies  \
# 2044                     64.95              67.34  Drought-resistant Crops
# 2048                     59.39              62.76  Drought-resistant Crops
# 2053                     34.56              58.80         Water Management
# 2089                     55.99              29.98  Drought-resistant Crops
# 2106                     63.88              25.00         Water Management
# 2163                     49.27              25.00          Organic Farming
# 2224                     36.45              25.00         Water Management
# 2311                     90.27              25.00          Organic Farming
# 2372                     29.93              25.00         Water Management
# 2378                     25.85              25.64            Crop Rotation
# 2446                     18.74              25.00            No Adaptation
# 2456                     63.52              25.00            No Adaptation
# 2479                     82.84              25.00            No Adaptation
# 2488                     89.66              25.00          Organic Farming
# 2493                     15.76              25.00         Water Management
# 2497                      1.95              25.00          Organic Farming
# 2502                     31.35              25.00            No Adaptation
# 2581                     34.27              25.00          Organic Farming
# 2617                     22.51              25.00            Crop Rotation
# 2622                     11.09              25.00            No Adaptation
#
#       Economic_Impact_Million_USD
# 2044                       830.80
# 2048                       908.60
# 2053                       849.04
# 2089                       840.18
# 2106                       890.10
# 2163                       860.73
# 2224                       880.10
# 2311                       771.10
# 2372                       861.82
# 2378                       663.97
# 2446                       747.77
# 2456                       719.53
# 2479                       859.67
# 2488                       803.10
# 2493                       763.34
# 2497                       642.42
# 2502                       723.40
# 2581                       812.20
# 2617                       777.63
# 2622                       775.47

# %%
mask2 = (df['Year'] == 1990) & (df['Country'] == 'Brazil') & (df['Region'] == 'South') 
filtered2 = df.loc[mask2, ['Year','Country','Region','Crop_Type','Average_Temperature_C','Adaptation_Strategies','Economic_Impact_Million_USD']]
filtered2.head(20)
# Out:
#       Year Country Region Crop_Type  Average_Temperature_C  \
# 2022  1990  Brazil  South  Soybeans                  15.73
# 2026  1990  Brazil  South      Rice                  15.84
# 2027  1990  Brazil  South      Rice                  15.70
# 2029  1990  Brazil  South     Wheat                  15.27
#
#         Adaptation_Strategies  Economic_Impact_Million_USD
# 2022            No Adaptation                       566.62
# 2026         Water Management                       521.14
# 2027  Drought-resistant Crops                       745.80
# 2029            No Adaptation                       564.83

# %%
mask3 = (df['Year'].isin([1990, 1995, 2000, 2005, 2011,2015, 2020, 2024])) & (df['Country'] == 'Brazil') & (df['Crop_Type'] == 'Wheat') 
filtered3 = df.loc[mask3, ['Year','Country','Region','Crop_Type','Average_Temperature_C','Adaptation_Strategies','Economic_Impact_Million_USD']]
#orden2 = filtered3.sort_values(by=['Year'], ascending=[True])
orden2 = filtered3.sort_values(by=['Year', 'Economic_Impact_Million_USD'], ascending=[True, False])
resultado_final = orden2.drop_duplicates(subset=['Year'], keep='first')
#orden2.head(20)
resultado_final.head(20)
# Out:
#       Year Country     Region Crop_Type  Average_Temperature_C  \
# 2029  1990  Brazil      South     Wheat                  15.27
# 2163  1995  Brazil      North     Wheat                  15.77
# 2309  2000  Brazil      South     Wheat                  15.81
# 2437  2005  Brazil  Northeast     Wheat                  15.90
# 2581  2011  Brazil      North     Wheat                  15.91
# 2709  2015  Brazil      North     Wheat                  16.28
# 2831  2020  Brazil      South     Wheat                  15.76
# 2934  2024  Brazil  Northeast     Wheat                  16.29
#
#      Adaptation_Strategies  Economic_Impact_Million_USD
# 2029         No Adaptation                       564.83
# 2163       Organic Farming                       860.73
# 2309         No Adaptation                       848.34
# 2437       Organic Farming                       987.82
# 2581       Organic Farming                       812.20
# 2709         Crop Rotation                       917.75
# 2831         Crop Rotation                       828.37
# 2934      Water Management                       832.28

# %%
#Mostrar graficos comparativos entre 1990 - 2024
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.plot(
    resultado_final['Year'],
    resultado_final['Average_Temperature_C'],
    marker='o'
)

plt.title('Temperaturas promedio del trigo (Brasil)')
plt.xlabel('Year')
plt.ylabel('Temperatura promedio (°C)')
plt.grid(True)

plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(
    orden2['Year'],
    orden2['Economic_Impact_Million_USD']
)

plt.title('Impacto económico de la producción de trigo en Brasil')
plt.xlabel('Year')
plt.ylabel('Impacto económico (Million USD)')
plt.xticks(orden2['Year'], rotation=45)
plt.grid(axis='y')

plt.show()

# %%
fig, ax1 = plt.subplots(figsize=(10,5))

# Temperatura
ax1.plot(
    resultado_final['Year'],
    resultado_final['Average_Temperature_C'],
    marker='o',
    label='Temperatura'
)
ax1.set_xlabel('Año')
ax1.set_ylabel('Temperatura promedio (°C)')
ax1.grid(True)
plt.legend(loc='upper left',bbox_to_anchor=(0.1, -0.1))

# Impacto económico
ax2 = ax1.twinx()
ax2.bar(
    resultado_final['Year'],
    resultado_final['Economic_Impact_Million_USD'],
    alpha=0.3,
    label='Impacto económico'
)
ax2.set_ylabel('Impacto económico(Million USD)')


plt.title('Temperatura vs. impacto económico del trigo en Brasil')
plt.legend(loc='upper right', bbox_to_anchor=(0.9, -0.1))
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('climate_change_refact.csv')
def filtrar_agricultura(
    df,
    country,
    region,
    crop,
    years,
):
    base_columns = [
        'Year',
        'Country',
        'Region',
        'Crop_Type',
        'Average_Temperature_C',
        'Adaptation_Strategies',
        'Economic_Impact_Million_USD',
        'Fertilizer_Use_KG_per_HA',
        'Pesticide_Use_KG_per_HA',
        'Irrigation_Access_%',
        'Crop_Yield_MT_per_HA'
    ]

    mask = (
        df['Year'].isin(years) &
        (df['Country'] == country) &
        (df['Region'] == region) &
        (df['Crop_Type'] == crop)
    )

    resultado = (
        df.loc[mask, base_columns]
          .sort_values(by='Year')
          .reset_index(drop=True)
    )

    return resultado

# %%
def graficar_serie_temporal(
    df,
    y_col,
    titulo,
    y_label
):
    plt.figure(figsize=(10,5))
    
    plt.plot(
        df['Year'],
        df[y_col],
        marker='o'
    )
    
    plt.title(titulo)
    plt.xlabel('Year')
    plt.ylabel(y_label)
    plt.grid(True)
    plt.show()

# %%
years = [1990, 1995, 2000, 2005, 2011, 2015, 2020, 2024]

datos = filtrar_agricultura(
    df=df,
    country='Brazil',
    region='South',
    crop='Corn',
    years=years,
)

graficar_serie_temporal(
    df=datos,
    y_col='Crop_Yield_MT_per_HA',
    titulo='Fertilizantes en trigo – Sur de Brasil',
    y_label='kg por hectárea'
)

#datos_trigo_sur_brasil.head(20)

# %%
plt.figure(figsize=(6,5))
plt.scatter(
    datos['Irrigation_Access_%'],
    datos['Economic_Impact_Million_USD']
)
plt.xlabel('Acceso a riego (%)')
plt.ylabel('Impacto económico (M USD)')
plt.title('Riego vs impacto económico – Trigo en Brasil')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.scatter(
    datos['Fertilizer_Use_KG_per_HA'],
    datos['Crop_Yield_MT_per_HA']
)
plt.xlabel('Fertilizantes (kg/ha)')
plt.ylabel('Rendimiento (MT/ha)')
plt.title('Fertilizantes vs rendimiento – Trigo en Brasil')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8,5))
datos.boxplot(
    column='Crop_Yield_MT_per_HA',
    by='Adaptation_Strategies'
)
plt.title('Rendimiento por estrategia de adaptación')
plt.suptitle('')
plt.ylabel('MT/ha')
plt.show()

# %%
#Agrupación por categorías

counts = orden['Adaptation_Strategies'].value_counts()
top5 = counts.head(5).index
adaptStrat_cat = df['Adaptation_Strategies'].where(df['Adaptation_Strategies'].isin(top5), 'Altres')
adaptStrat_cat = adaptStrat_cat.astype('category')
print('Categories:', adaptStrat_cat.cat.categories)
adaptStrat_cat.value_counts()
# Out:
# Categories: Index(['Crop Rotation', 'Drought-resistant Crops', 'No Adaptation',
#        'Organic Farming', 'Water Management'],
#       dtype='object')
# Adaptation_Strategies
# Water Management           2049
# No Adaptation              2024
# Drought-resistant Crops    1995
# Organic Farming            1975
# Crop Rotation              1957
# Name: count, dtype: int64

# %%
counts1 = orden['Adaptation_Strategies'].value_counts()
secondTop5 = counts1.head(5).index
adaptStrat_cat1 = orden['Adaptation_Strategies'].where(orden['Adaptation_Strategies'].isin(secondTop5), 'Altres')
adaptStrat_cat1 = adaptStrat_cat1.astype('category')
print('Categories:', adaptStrat_cat1.cat.categories)
adaptStrat_cat1.value_counts()
# Out:
# Categories: Index(['Crop Rotation', 'Drought-resistant Crops', 'No Adaptation',
#        'Organic Farming', 'Water Management'],
#       dtype='object')
# Adaptation_Strategies
# No Adaptation              11
# Organic Farming             8
# Water Management            7
# Crop Rotation               4
# Drought-resistant Crops     4
# Name: count, dtype: int64

# %%
# Radio estratégias de adaptación
explode = [0.1, 0, 0, 0]

plt.figure(figsize=(10,5))
plt.pie(x = adaptStrat_cat.value_counts(),labels = adaptStrat_cat.cat.categories, autopct='%1.1f%%')
#plt.pie(x = adaptStrat_cat.value_counts(), autopct='%1.1f%%')
#plt.legend(adaptStrat_cat.cat.categories)
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.pie(x = adaptStrat_cat1.value_counts(),labels = adaptStrat_cat1.cat.categories, autopct='%1.1f%%')
#plt.pie(x = adaptStrat_cat.value_counts(), autopct='%1.1f%%')
#plt.legend(adaptStrat_cat.cat.categories)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Extraer los datos de las columnas
x = filtered3['Average_Temperature_C']
y = filtered3['Economic_Impact_Million_USD']

# 2. Calcular la línea de tendencia (regresión lineal simple)
# np.polyfit calcula la pendiente (m) y la intersección (b)
m, b = np.polyfit(x, y, 1)

# 3. Crear el gráfico
plt.figure(figsize=(10, 6))

# Dibujar los puntos (Scatter)
plt.scatter(x, y, color='steelblue', alpha=0.7, label='Datos anuales', s=80)

# Dibujar la línea de tendencia
# La fórmula es: y = mx + b
plt.plot(x, m*x + b, color='red', linewidth=2, label=f'Tendencia (Pendiente: {m:.2f})')

# 4. Personalización técnica
plt.title('Correlación: Temperatura vs Impacto Económico', fontsize=14)
plt.xlabel('Temperatura Media (°C)', fontsize=12)
plt.ylabel('Millones USD', fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)

plt.show()
